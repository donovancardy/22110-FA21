# %%
import pandas as pd
import json
import matplotlib as plt

# %%
with open(r"/Users/donovancardy/Desktop/cardy.21_20210907/likes/liked_posts.json") as j:
    dat = json.load(j)

# %%
dat
# Out:
# {'likes_media_likes': [{'title': 'wtffunfacts',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Y_bDn6gqy_/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1371104683}]},
#   {'title': 'wtffunfacts',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/Y_tyRYAq8Z/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1371104661}]},
#   {'title': 'wtffunfacts',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/ZBU5nqAqxQ/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1371104634}]},
#   {'title': 'wtffunfacts',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/ZB7ARJAq2N/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1371104628}]},
#   {'title': 'wtffunfacts',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/ZLKpmZgq50/',
# ...

# %%
dat.keys()
# Out:
# dict_keys(['likes_media_likes'])

# %%
dat['likes_media_likes']
# Out:
# [{'title': 'wtffunfacts',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Y_bDn6gqy_/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1371104683}]},
#  {'title': 'wtffunfacts',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Y_tyRYAq8Z/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1371104661}]},
#  {'title': 'wtffunfacts',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/ZBU5nqAqxQ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1371104634}]},
#  {'title': 'wtffunfacts',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/ZB7ARJAq2N/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1371104628}]},
#  {'title': 'wtffunfacts',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/ZLKpmZgq50/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1371104599}]},
# ...

# %%
type(dat['likes_media_likes'])
# Out:
# list

# %%
dat['likes_media_likes'][0]
# Out:
# {'title': 'wtffunfacts',
#  'media_list_data': [],
#  'string_list_data': [{'href': 'https://www.instagram.com/p/Y_bDn6gqy_/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104683}]}

# %%
df_likes = pd.DataFrame(dat)

# %%
df_likes
# Out:
#                                       likes_media_likes
# 0     {'title': 'wtffunfacts', 'media_list_data': []...
# 1     {'title': 'wtffunfacts', 'media_list_data': []...
# 2     {'title': 'wtffunfacts', 'media_list_data': []...
# 3     {'title': 'wtffunfacts', 'media_list_data': []...
# 4     {'title': 'wtffunfacts', 'media_list_data': []...
# ...                                                 ...
# 5209  {'title': 'iamjeanniek', 'media_list_data': []...
# 5210  {'title': 'kspurs16', 'media_list_data': [], '...
# 5211  {'title': 'worldstar', 'media_list_data': [], ...
# 5212  {'title': 'mariayoung19', 'media_list_data': [...
# 5213  {'title': '_laurenshanley', 'media_list_data':...
#
# [5214 rows x 1 columns]

# %%
df_likes = pd.DataFrame(dat['likes_media_likes'])

# %%
df_likes
# Out:
#                title media_list_data  \
# 0        wtffunfacts              []
# 1        wtffunfacts              []
# 2        wtffunfacts              []
# 3        wtffunfacts              []
# 4        wtffunfacts              []
# ...              ...             ...
# 5209     iamjeanniek              []
# 5210        kspurs16              []
# 5211       worldstar              []
# 5212    mariayoung19              []
# 5213  _laurenshanley              []
#
#                                        string_list_data
# 0     [{'href': 'https://www.instagram.com/p/Y_bDn6g...
# 1     [{'href': 'https://www.instagram.com/p/Y_tyRYA...
# 2     [{'href': 'https://www.instagram.com/p/ZBU5nqA...
# 3     [{'href': 'https://www.instagram.com/p/ZB7ARJA...
# 4     [{'href': 'https://www.instagram.com/p/ZLKpmZg...
# ...                                                 ...
# 5209  [{'href': 'https://www.instagram.com/p/BZq8pmi...
# 5210  [{'href': 'https://www.instagram.com/p/BZrO6-q...
# ...

# %%
type('string_list_data')
# Out:
# str

# %%
df_title = pd.DataFrame(x['title'] for x in dat['likes_media_likes'])

# %%
df_title
# Out:
#                    0
# 0        wtffunfacts
# 1        wtffunfacts
# 2        wtffunfacts
# 3        wtffunfacts
# 4        wtffunfacts
# ...              ...
# 5209     iamjeanniek
# 5210        kspurs16
# 5211       worldstar
# 5212    mariayoung19
# 5213  _laurenshanley
#
# [5214 rows x 1 columns]

# %%
instagram_usernames = [x['string_list_data'] for x in dat['likes_media_likes']]

# %%
instagram_usernames
# Out:
# [[{'href': 'https://www.instagram.com/p/Y_bDn6gqy_/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104683}],
#  [{'href': 'https://www.instagram.com/p/Y_tyRYAq8Z/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104661}],
#  [{'href': 'https://www.instagram.com/p/ZBU5nqAqxQ/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104634}],
#  [{'href': 'https://www.instagram.com/p/ZB7ARJAq2N/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104628}],
#  [{'href': 'https://www.instagram.com/p/ZLKpmZgq50/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104599}],
#  [{'href': 'https://www.instagram.com/p/ZLs0segq2_/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104567}],
#  [{'href': 'https://www.instagram.com/p/ZOejZwgq8Z/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104548}],
#  [{'href': 'https://www.instagram.com/p/ZQDUn1Aq-E/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104541}],
# ...

# %%
timestamp = [x for x in instagram_usernames]

# %%
timestamp
# Out:
# [[{'href': 'https://www.instagram.com/p/Y_bDn6gqy_/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104683}],
#  [{'href': 'https://www.instagram.com/p/Y_tyRYAq8Z/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104661}],
#  [{'href': 'https://www.instagram.com/p/ZBU5nqAqxQ/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104634}],
#  [{'href': 'https://www.instagram.com/p/ZB7ARJAq2N/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104628}],
#  [{'href': 'https://www.instagram.com/p/ZLKpmZgq50/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104599}],
#  [{'href': 'https://www.instagram.com/p/ZLs0segq2_/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104567}],
#  [{'href': 'https://www.instagram.com/p/ZOejZwgq8Z/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104548}],
#  [{'href': 'https://www.instagram.com/p/ZQDUn1Aq-E/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1371104541}],
# ...

# %%
df_timestamp = pd.DataFrame(timestamp)

# %%
df_timestamp
# Out:
#                                                       0
# 0     {'href': 'https://www.instagram.com/p/Y_bDn6gq...
# 1     {'href': 'https://www.instagram.com/p/Y_tyRYAq...
# 2     {'href': 'https://www.instagram.com/p/ZBU5nqAq...
# 3     {'href': 'https://www.instagram.com/p/ZB7ARJAq...
# 4     {'href': 'https://www.instagram.com/p/ZLKpmZgq...
# ...                                                 ...
# 5209  {'href': 'https://www.instagram.com/p/BZq8pmiF...
# 5210  {'href': 'https://www.instagram.com/p/BZrO6-qF...
# 5211  {'href': 'https://www.instagram.com/p/BZpWBWvg...
# 5212  {'href': 'https://www.instagram.com/p/BZm2pYHh...
# 5213  {'href': 'https://www.instagram.com/p/BZcQYLGA...
#
# [5214 rows x 1 columns]

# %%
timestamp = [x[0] for x in instagram_usernames]

# %%
timestamp
# Out:
# [{'href': 'https://www.instagram.com/p/Y_bDn6gqy_/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371104683},
#  {'href': 'https://www.instagram.com/p/Y_tyRYAq8Z/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371104661},
#  {'href': 'https://www.instagram.com/p/ZBU5nqAqxQ/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371104634},
#  {'href': 'https://www.instagram.com/p/ZB7ARJAq2N/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371104628},
#  {'href': 'https://www.instagram.com/p/ZLKpmZgq50/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371104599},
#  {'href': 'https://www.instagram.com/p/ZLs0segq2_/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371104567},
#  {'href': 'https://www.instagram.com/p/ZOejZwgq8Z/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371104548},
#  {'href': 'https://www.instagram.com/p/ZQDUn1Aq-E/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1371104541},
#  {'href': 'https://www.instagram.com/p/ZRg-iggq73/',
# ...

# %%
df_timestamp = pd.DataFrame(timestamp)

# %%
df_timestamp
# Out:
#                                                    href value   timestamp
# 0               https://www.instagram.com/p/Y_bDn6gqy_/  ð  1371104683
# 1               https://www.instagram.com/p/Y_tyRYAq8Z/  ð  1371104661
# 2               https://www.instagram.com/p/ZBU5nqAqxQ/  ð  1371104634
# 3               https://www.instagram.com/p/ZB7ARJAq2N/  ð  1371104628
# 4               https://www.instagram.com/p/ZLKpmZgq50/  ð  1371104599
# ...                                                 ...   ...         ...
# 5209           https://www.instagram.com/p/BZq8pmiFEIJ/  ð  1506862321
# 5210  https://www.instagram.com/p/BZrO6-qFJB91ynl_ZF...  ð  1506825425
# 5211           https://www.instagram.com/p/BZpWBWvgGG_/  ð  1506733743
# 5212  https://www.instagram.com/p/BZm2pYHhUu56jZQaX6...  ð  1506653179
# 5213  https://www.instagram.com/p/BZcQYLGACDFxidle2G...  ð  1506294820
#
# [5214 rows x 3 columns]

# %% [markdown]
# This data was collected by Instagram and me. I chose to follow these accounts and like their posts. The way Instagram has sort of collected this data is by recommending posts to me that I may like based on my previous likes. This data was collected to give people a view of what I may find interesting or really like. The way I showed this data, I tried a few different times to get a data frame that showed both the post information and also the timestamp. Following the in class examples and also digging a little deeper to figure out how to incorporate the two, I came up with this data frame that shows both. It is reliable in the way that it shows what I liked in a table but unreliable because I still can't really see who these usernames are.

# %%
df_timestamp['title'] = df_likes['title']

# %%
df_timestamp
# Out:
#                                                    href value   timestamp  \
# 0               https://www.instagram.com/p/Y_bDn6gqy_/  ð  1371104683
# 1               https://www.instagram.com/p/Y_tyRYAq8Z/  ð  1371104661
# 2               https://www.instagram.com/p/ZBU5nqAqxQ/  ð  1371104634
# 3               https://www.instagram.com/p/ZB7ARJAq2N/  ð  1371104628
# 4               https://www.instagram.com/p/ZLKpmZgq50/  ð  1371104599
# ...                                                 ...   ...         ...
# 5209           https://www.instagram.com/p/BZq8pmiFEIJ/  ð  1506862321
# 5210  https://www.instagram.com/p/BZrO6-qFJB91ynl_ZF...  ð  1506825425
# 5211           https://www.instagram.com/p/BZpWBWvgGG_/  ð  1506733743
# 5212  https://www.instagram.com/p/BZm2pYHhUu56jZQaX6...  ð  1506653179
# 5213  https://www.instagram.com/p/BZcQYLGACDFxidle2G...  ð  1506294820
#
#                title
# 0        wtffunfacts
# 1        wtffunfacts
# ...

# %%
df_timestamp.groupby(['title']).min()
# Out:
#                                                                              href  \
# title
# 3.1415926535897932384626433832            https://www.instagram.com/p/8FuASrMUyl/
# 344pz                                    https://www.instagram.com/p/CSXfkLvn8O9/
# 3luckeestar3                    https://www.instagram.com/p/Boc7j9GAgNjQ_onY8d...
# 4.little_bit.11                           https://www.instagram.com/p/n6MMS9The9/
# _3.1415926535897932384626433._            https://www.instagram.com/p/zC69ZQSSEO/
# ...                                                                           ...
# youre.beautiful.to.us                     https://www.instagram.com/p/zDCfndAQ9x/
# yousif.kaskas                             https://www.instagram.com/p/nvIMbkKRDU/
# youujustrealizeddd                        https://www.instagram.com/p/Z0WW3-iZhP/
# zachadair1                      https://www.instagram.com/p/BBEMdI6IitI1wpxdmA...
# ...

# %%
df_timestamp.groupby(['title']).max()
# Out:
#                                                                              href  \
# title
# 3.1415926535897932384626433832            https://www.instagram.com/p/sZVSxAMU6s/
# 344pz                                    https://www.instagram.com/p/CSXfkLvn8O9/
# 3luckeestar3                    https://www.instagram.com/p/Boc7j9GAgNjQ_onY8d...
# 4.little_bit.11                           https://www.instagram.com/p/n6MMS9The9/
# _3.1415926535897932384626433._            https://www.instagram.com/p/zC8MeRSSGe/
# ...                                                                           ...
# youre.beautiful.to.us                     https://www.instagram.com/p/zDCfndAQ9x/
# yousif.kaskas                             https://www.instagram.com/p/nvIMbkKRDU/
# youujustrealizeddd                        https://www.instagram.com/p/bJVmcBiZix/
# zachadair1                      https://www.instagram.com/p/BNNnZhVg5VTt2JGZV-...
# ...

# %%
df_timestamp.groupby(['timestamp']).max()
# Out:
#                                                          href value  \
# timestamp
# 1363118706            https://www.instagram.com/p/WvMT5tBrlJ/  ð
# 1363118899            https://www.instagram.com/p/Wu6uu9BruM/  ð
# 1363135237            https://www.instagram.com/p/WxsAOjhrp-/  ð
# 1363307180            https://www.instagram.com/p/W2nxmTBrto/  ð
# 1363408026            https://www.instagram.com/p/W5g-qDBrpT/  ð
# ...                                                       ...   ...
# 1630549098           https://www.instagram.com/p/CTOxhBijLsk/  ð
# 1630700642           https://www.instagram.com/p/CTXxHUzlUWE/  ð
# 1630949523           https://www.instagram.com/p/CTfKU7ILkhk/  ð
# 1630953846           https://www.instagram.com/p/CTfSa0bHZ4F/  ð
# 1630983745  https://www.instagram.com/p/CTfZgSNJ-rb1HF-G-I...  ð
#
#                         title
# timestamp
# 1363118706  awesomeinventions
# 1363118899  awesomeinventions
# 1363135237  awesomeinventions
# ...

# %%
df_timestamp.groupby(['timestamp']).min()
# Out:
#                                                          href value  \
# timestamp
# 1363118706            https://www.instagram.com/p/WvMT5tBrlJ/  ð
# 1363118899            https://www.instagram.com/p/Wu6uu9BruM/  ð
# 1363135237            https://www.instagram.com/p/WxsAOjhrp-/  ð
# 1363307180            https://www.instagram.com/p/W2nxmTBrto/  ð
# 1363408026            https://www.instagram.com/p/W5g-qDBrpT/  ð
# ...                                                       ...   ...
# 1630549098           https://www.instagram.com/p/CTOxhBijLsk/  ð
# 1630700642           https://www.instagram.com/p/CTXxHUzlUWE/  ð
# 1630949523           https://www.instagram.com/p/CTfKU7ILkhk/  ð
# 1630953846           https://www.instagram.com/p/CTfSa0bHZ4F/  ð
# 1630983745  https://www.instagram.com/p/CTfZgSNJ-rb1HF-G-I...  ð
#
#                         title
# timestamp
# 1363118706  awesomeinventions
# 1363118899  awesomeinventions
# 1363135237  awesomeinventions
# ...

# %% [markdown]
# After incorporating the usernames, timestamps, and href's, these are some data frames that I came up with. This is all a little confusing to me, so I decided to make a few tables that were grouped and sorted a little differently from each other. I found that the ones grouped by timestamp is a little more useful than the ones grouped by the title. I used the "your_topics.json" file to make the hypothesis that the content or posts that I like on Instagram allows Instagram to create new topic interests for my account then allowing me to see content more suited for me, then the more I like the new posts I see, the more new topics my account will correlate with. This will then make me and the accounts I interact with have more in common. Instead of just my personal Instagram account data, it would be more helpful to be able to see the data files for the accounts I interact with and have similar topics in common.

# %% [markdown]
# # Donovan Cardy
# *9/21/21*
# #### Likes Report
#     Looking back at the in class examples, I was able to pull data out from my "liked_posts.json" data file. For each data frame I made, I tried to name them according to what kind of data I was looking for. I had to take the data that was given in a list and make it into a data frame table. Doing this data wrangling helped me organize the liked posts and make it into a table that was easier to read and see. After stating my hypothesis and looking at the data I came up with, I can see that a lot of the posts I have liked do line up with the topics that Instagram provided for me in the topics file. I can see that the topics more correlate with the more recent posts I have liked rather than the older ones. To further test this data, I would be ideal to link the topics and liked posts together to have a visual representation of how the two are related and which topics relate to which likes. And then also what topics are irrelevant compared to the posts I've liked. I could also re-download this data at a later time, like a year from now, and compare the results of that data to this current data to see what lines up, what's new, what topics have went away, and how relevant those topics are to the liked posts from that data.
